# %%
# Cell 1: Imports
from pathlib import Path
import os
from dotenv import load_dotenv
from neuroalign_preprocessing.loaders import AnatomicalLoader, DiffusionLoader, QuestionnaireLoader
from neuroalign_preprocessing.preprocessing import FeatureStore

# Load environment variables
load_dotenv()
# Out:
# True

# %%
import pandas as pd

store = FeatureStore("/media/storage/neuroalign/data")

# %%
gm = store.load_long("diffusion_DSIStudio")

# %%
gm["session_id"].nunique()
# Out:
# 2354

# %%
# Cell 3: Test loading one session
# Replace with your actual subject/session
test_subject = "0048R"
test_session = "202303161349"

anat_data = anat_loader.load_session(
    subject=test_subject,
    session=test_session
)

if anat_data is not None:
    print(f"✓ Loaded {len(anat_data)} regional features")
    print(f"Modalities: {anat_data['modality'].unique()}")
    print(anat_data.head())
else:
    print("✗ Session not found - check paths and subject/session IDs")
# Out:
# ✓ Loaded 1368 regional features
# Modalities: ['gm' 'wm' 'ct']
#    index     label network_label      label_7network  index_17network  \
# 0      1  LH_Vis_1           Vis  7Networks_LH_Vis_1             61.0
# 1      2  LH_Vis_2           Vis  7Networks_LH_Vis_2            193.0
# 2      3  LH_Vis_3           Vis  7Networks_LH_Vis_3              1.0
# 3      4  LH_Vis_4           Vis  7Networks_LH_Vis_4             13.0
# 4      5  LH_Vis_5           Vis  7Networks_LH_Vis_5              2.0
#
#                      label_17network network_label_17network atlas_name  \
# 0  17Networks_LH_DorsAttnA_TempOcc_2               DorsAttnA      4S456
# 1       17Networks_LH_DefaultC_PHC_2                DefaultC      4S456
# 2      17Networks_LH_VisCent_ExStr_1                 VisCent      4S456
# 3   17Networks_LH_VisPeri_ExStrInf_1                 VisPeri      4S456
# 4      17Networks_LH_VisCent_ExStr_2                 VisCent      4S456
#
#    network_id  volume_mm3  ...  robust_std  mad_median      mean       std  \
# 0         NaN    2875.500  ...    0.174347    0.096446  0.499111  0.200660
# 1         NaN    3398.625  ...    0.215922    0.116727  0.588974  0.230079
# 2         NaN    2592.000  ...    0.205142    0.110522  0.474460  0.205142
# 3         NaN    3418.875  ...    0.233215    0.132762  0.539623  0.233215
# 4         NaN    3395.250  ...    0.235117    0.179390  0.422563  0.235117
#
#      median         sum  modality  metric  subject_code    session_id
# 0  0.578435  425.242668        gm  volume         0048R  202303161349
# 1  0.678658  593.096686        gm  volume         0048R  202303161349
# 2  0.548793  364.385081        gm  volume         0048R  202303161349
# 3  0.626174  546.638369        gm  volume         0048R  202303161349
# 4  0.481146  425.098838        gm  volume         0048R  202303161349
#
# [5 rows x 26 columns]

# %%
anat_data
# Out:
#       index                label network_label      label_7network  \
# 0         1             LH_Vis_1           Vis  7Networks_LH_Vis_1
# 1         2             LH_Vis_2           Vis  7Networks_LH_Vis_2
# 2         3             LH_Vis_3           Vis  7Networks_LH_Vis_3
# 3         4             LH_Vis_4           Vis  7Networks_LH_Vis_4
# 4         5             LH_Vis_5           Vis  7Networks_LH_Vis_5
# ...     ...                  ...           ...                 ...
# 1363    452   Cerebellar_Region6           NaN                 NaN
# 1364    453   Cerebellar_Region7           NaN                 NaN
# 1365    454   Cerebellar_Region8           NaN                 NaN
# 1366    455   Cerebellar_Region9           NaN                 NaN
# 1367    456  Cerebellar_Region10           NaN                 NaN
#
#       index_17network                    label_17network  \
# 0                61.0  17Networks_LH_DorsAttnA_TempOcc_2
# 1               193.0       17Networks_LH_DefaultC_PHC_2
# 2                 1.0      17Networks_LH_VisCent_ExStr_1
# 3                13.0   17Networks_LH_VisPeri_ExStrInf_1
# 4                 2.0      17Networks_LH_VisCent_ExStr_2
# ...               ...                                ...
# 1363              NaN                                NaN
# 1364              NaN                                NaN
# 1365              NaN                                NaN
# 1366              NaN                                NaN
# 1367              NaN                                NaN
#
#      network_label_17network  atlas_name  network_id  volume_mm3  ...  \
# 0                  DorsAttnA       4S456         NaN    2875.500  ...
# 1                   DefaultC       4S456         NaN    3398.625  ...
# 2                    VisCent       4S456         NaN    2592.000  ...
# 3                    VisPeri       4S456         NaN    3418.875  ...
# 4                    VisCent       4S456         NaN    3395.250  ...
# ...                      ...         ...         ...         ...  ...
# 1363                     NaN  Cerebellum         NaN   28535.625  ...
# 1364                     NaN  Cerebellum         NaN   11194.875  ...
# 1365                     NaN  Cerebellum         NaN   16031.250  ...
# 1366                     NaN  Cerebellum         NaN    8322.750  ...
# 1367                     NaN  Cerebellum         NaN   10671.750  ...
#
#       robust_std  mad_median      mean       std    median           sum  \
# 0       0.174347    0.096446  0.499111  0.200660  0.578435    425.242668
# 1       0.215922    0.116727  0.588974  0.230079  0.678658    593.096686
# 2       0.205142    0.110522  0.474460  0.205142  0.548793    364.385081
# 3       0.233215    0.132762  0.539623  0.233215  0.626174    546.638369
# 4       0.235117    0.179390  0.422563  0.235117  0.481146    425.098838
# ...          ...         ...       ...       ...       ...           ...
# 1363    0.876409    0.551500  1.618177  0.876409  1.512700  14856.485625
# 1364    0.358251    0.280800  1.518926  0.499398  1.561700   5308.646766
# 1365    0.621113    0.381800  1.957049  0.714323  2.103200   9630.639757
# 1366    0.796211    0.505000  1.915157  0.796211  1.885400   4985.154074
# 1367    0.949548    0.644900  2.050229  0.949548  2.307150   6892.869426
#
#       modality     metric  subject_code    session_id
# 0           gm     volume         0048R  202303161349
# 1           gm     volume         0048R  202303161349
# 2           gm     volume         0048R  202303161349
# 3           gm     volume         0048R  202303161349
# 4           gm     volume         0048R  202303161349
# ...        ...        ...           ...           ...
# 1363        ct  thickness         0048R  202303161349
# 1364        ct  thickness         0048R  202303161349
# 1365        ct  thickness         0048R  202303161349
# 1366        ct  thickness         0048R  202303161349
# 1367        ct  thickness         0048R  202303161349
#
# [1368 rows x 26 columns]

# %%
# Cell 4: Test Diffusion Loader
qsiparc_path = Path(os.getenv("QSIPARC_PATH"))
qsirecon_path = Path(os.getenv("QSIRECON_PATH"))

diff_loader = DiffusionLoader(
    qsiparc_path=qsiparc_path,
    qsirecon_path=qsirecon_path
)

print(f"Diffusion loader created")
print(f"Available workflows: {diff_loader.workflows}")

# Cell 5: Test Questionnaire Loader
# Out:
# Diffusion loader created
# Available workflows: ['DSIStudio', 'MRtrix3_act-HSVS', 'DIPYDKI', 'DIPYMAPMRI', 'AMICONODDI']

# %%
# diff_loader.load_session(
#     subject=test_subject,
#     session=test_session)
session_dir = diff_loader.get_session_directory(
    subject=test_subject,
    session=test_session,
    workflow="AMICONODDI")

for tsv_file in session_dir.glob("*_parc.tsv"):
    print(f"Found TSV file: {tsv_file}")
# session_dir
# Out:
# Found TSV file: /mnt/62/Processed_Data/derivatives/qsiparc/qsirecon-AMICONODDI/sub-0048R/ses-202303161349/dwi/atlas-4S456Parcels/sub-0048R_ses-202303161349_atlas-4S456Parcels_space-MNI152NLin2009cAsym_res-01_model-noddi_param-tf_parc.tsv
# Found TSV file: /mnt/62/Processed_Data/derivatives/qsiparc/qsirecon-AMICONODDI/sub-0048R/ses-202303161349/dwi/atlas-4S456Parcels/sub-0048R_ses-202303161349_atlas-4S456Parcels_space-MNI152NLin2009cAsym_res-01_model-noddi_param-isovf_parc.tsv
# Found TSV file: /mnt/62/Processed_Data/derivatives/qsiparc/qsirecon-AMICONODDI/sub-0048R/ses-202303161349/dwi/atlas-4S456Parcels/sub-0048R_ses-202303161349_atlas-4S456Parcels_space-MNI152NLin2009cAsym_res-01_model-noddi_param-od_desc-modulated_parc.tsv
# Found TSV file: /mnt/62/Processed_Data/derivatives/qsiparc/qsirecon-AMICONODDI/sub-0048R/ses-202303161349/dwi/atlas-4S456Parcels/sub-0048R_ses-202303161349_atlas-4S456Parcels_space-MNI152NLin2009cAsym_res-01_model-noddi_param-nrmse_parc.tsv
# Found TSV file: /mnt/62/Processed_Data/derivatives/qsiparc/qsirecon-AMICONODDI/sub-0048R/ses-202303161349/dwi/atlas-4S456Parcels/sub-0048R_ses-202303161349_atlas-4S456Parcels_space-MNI152NLin2009cAsym_res-01_model-noddi_param-icvf_parc.tsv
# Found TSV file: /mnt/62/Processed_Data/derivatives/qsiparc/qsirecon-AMICONODDI/sub-0048R/ses-202303161349/dwi/atlas-4S456Parcels/sub-0048R_ses-202303161349_atlas-4S456Parcels_space-MNI152NLin2009cAsym_res-01_model-noddi_param-rmse_parc.tsv
# Found TSV file: /mnt/62/Processed_Data/derivatives/qsiparc/qsirecon-AMICONODDI/sub-0048R/ses-202303161349/dwi/atlas-4S456Parcels/sub-0048R_ses-202303161349_atlas-4S456Parcels_space-MNI152NLin2009cAsym_res-01_model-noddi_param-od_parc.tsv
# Found TSV file: /mnt/62/Processed_Data/derivatives/qsiparc/qsirecon-AMICONODDI/sub-0048R/ses-202303161349/dwi/atlas-4S456Parcels/sub-0048R_ses-202303161349_atlas-4S456Parcels_space-MNI152NLin2009cAsym_res-01_model-noddi_param-icvf_desc-modulated_parc.tsv

# %%
quest_path = Path(os.getenv("QUESTIONNAIRE_CSV"))

quest_loader = QuestionnaireLoader(quest_path)
quest_data = quest_loader.load()

print(f"✓ Loaded questionnaire data for {len(quest_data)} participants")
print(f"\nFeature groups:")
for category, features in quest_loader.get_feature_groups().items():
    print(f"  {category}: {len(features)} features")

# Cell 6: Test participant summary
if test_subject in quest_data["Subject Code"].values:
    summary = quest_loader.summarize_participant(test_subject)
    print(f"\nParticipant {test_subject} summary:")
    for category, data in summary.items():
        print(f"\n{category}:")
        for key, value in data.items():
            print(f"  {key}: {value}")
